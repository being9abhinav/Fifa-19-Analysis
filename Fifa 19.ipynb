# %%
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
df=pd.read_excel(r"D:\Fifa2019.xlsx")

# %%
df.shape
# Out:
# (18085, 96)

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'player_positions', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'age', 'height_cm', 'weight_kg',
#        'club_name', 'league_name', 'club_joined', 'club_contract_valid_until',
#        'nationality_name', 'nation_jersey_number', 'preferred_foot',
#        'weak_foot', 'skill_moves', 'international_reputation', 'work_rate',
#        'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
# ...

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         155862  https://sofifa.com/player/155862/sergio-ramos-...
# 4         176580  https://sofifa.com/player/176580/luis-suarez/1...
# ...          ...                                                ...
# 18080     243961  https://sofifa.com/player/243961/evan-tweed/19...
# 18081     244638  https://sofifa.com/player/244638/juan-ramon-ru...
# 18082     244677  https://sofifa.com/player/244677/michael-baldi...
# 18083     244823  https://sofifa.com/player/244823/nicolas-fuent...
# 18084     245569  https://sofifa.com/player/245569/lee-watkins/1...
#
#               short_name player_positions  overall  potential    value_eur  \
# ...

# %%
df.isnull().sum()
# Out:
# sofifa_id           0
# player_url          0
# short_name          0
# player_positions    0
# overall             0
#                    ..
# rcb                 0
# rb                  0
# gk                  0
# player_face_url     0
# nation_flag_url     0
# Length: 96, dtype: int64

# %%
df['value_eur'].fillna(df['value_eur'].mean(),inplace=True)
df['wage_eur'].fillna(df['wage_eur'].mean(),inplace=True)
df['club_name'].fillna('No Club',inplace=True)
df['league_name'].fillna('No League',inplace=True)
df['club_joined'].fillna('Jul 1, 2018',inplace=True)
df['club_joined'].fillna('2022',inplace=True)
df['release_clause_eur'].fillna(df['release_clause_eur'].mean(),inplace=True)
df['pace'].fillna(df['pace'].mean(),inplace=True)
df['shooting'].fillna(df['shooting'].mean(),inplace=True)
df['passing'].fillna(df['passing'].mean(),inplace=True)
df['dribbling'].fillna(df['dribbling'].mean(),inplace=True)
df['defending'].fillna(df['defending'].mean(),inplace=True)
df['physic'].fillna(df['physic'].mean(),inplace=True)

# %%
df=pd.DataFrame(df
               )

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         155862  https://sofifa.com/player/155862/sergio-ramos-...
# 4         176580  https://sofifa.com/player/176580/luis-suarez/1...
# ...          ...                                                ...
# 18080     243961  https://sofifa.com/player/243961/evan-tweed/19...
# 18081     244638  https://sofifa.com/player/244638/juan-ramon-ru...
# 18082     244677  https://sofifa.com/player/244677/michael-baldi...
# 18083     244823  https://sofifa.com/player/244823/nicolas-fuent...
# 18084     245569  https://sofifa.com/player/245569/lee-watkins/1...
#
#               short_name player_positions  overall  potential    value_eur  \
# ...

# %%
df.to_csv(r"C:\Users\Abhinav Singh\OneDrive\Desktop\fifa.csv",index=False)
